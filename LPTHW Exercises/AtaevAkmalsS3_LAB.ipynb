# %% [markdown]
# <h1 style="text-align:center;">Akmal Ataev</h1>
# <h5 style="text-align:center;font-size:20px;">NYU Student ID aa44</h5>
# <h4 style="font-size:25px;text-align:center;">LAB</h4>

# %% [markdown]
# <h3>HW 40</h3>

# %%
class Song(object):
    
    def __init__(self,lyrics):
        self.lyrics = lyrics
    
    def sing_me_a_song(self):
        for line in self.lyrics:
            print(line)

happy_bday = Song(["Happy birthday to you",
                   "I don't want to get sued",
                   "So I'll stop right there"])

bulls_on_parade = Song(["They rally around the family",
                        "With pockets full of shells"])

happy_bday.sing_me_a_song()

bulls_on_parade.sing_me_a_song()
# Out:
# Happy birthday to you
# I don't want to get sued
# So I'll stop right there
# They rally around the family
# With pockets full of shells

# %% [markdown]
# <h3>HW 41</h3>

# %%
import random
from urllib.request import urlopen
import sys

WORD_URL = "http://learncodethehardway.org/words.txt"
WORDS = []

PHRASES = {
    "class %%%(%%%):":
      "Make a class named %%% that is-a %%%.",
    "class %%%(object):\n\tdef __init__(self, ***)" :
      "class %%% has-a __init__ that takes self and *** parameters.",
    "class %%%(object):\n\tdef ***(self, @@@)":
      "class %%% has-a function named *** that takes self and @@@ parameters.",
    "*** = %%%()":
      "Set *** to an instance of class %%%.",
    "***.***(@@@)":
      "From *** get the *** function, and call it with parameters self, @@@.",
    "***.*** = '***'":
      "From *** get the *** attribute and set it to '***'."
}

# do they want to drill phrases first
PHRASE_FIRST = False
if len(sys.argv) == 2 and sys.argv[1] == "english":
    PHRASE_FIRST = True

# load up the words from the website
for word in urlopen(WORD_URL).readlines():
    WORDS.append(word.strip().decode("utf-8"))

def convert(snippet, phrase):
    class_names = [w.capitalize() for w in random.sample(WORDS, snippet.count("%%%"))]
    other_names = random.sample(WORDS, snippet.count("***"))
    results = []
    param_names = []

    for i in range(0, snippet.count("@@@")):
        param_count = random.randint(1,3)
        param_names.append(', '.join(random.sample(WORDS, param_count)))

    for sentence in snippet, phrase:
        result = sentence[:]

        # fake class names
        for word in class_names:
            result = result.replace("%%%", word, 1)

        # fake other names
        for word in other_names:
            result = result.replace("***", word, 1)

        # fake parameter lists
        for word in param_names:
            result = result.replace("@@@", word, 1)

        results.append(result)

    return results

# keep going until they hit CTRL-D
try:
    while True:
        snippets = list(PHRASES.keys())
        random.shuffle(snippets)

        for snippet in snippets:
            phrase = PHRASES[snippet]
            question, answer = convert(snippet, phrase)
            if PHRASE_FIRST:
                question, answer = answer, question

            print(question)

            input("> ")
            print("ANSWER:  %s\n\n" % answer)
except EOFError:
    print("\nBye")
# Out:
# class Arithmetic(Butto):
# > 45
# ANSWER:  Make a class named Arithmetic that is-a Butto.
#
#
# class Cup(object):
# 	def __init__(self, cork)
# > 12
# ANSWER:  class Cup has-a __init__ that takes self and cork parameters.
#
#
# band.drink = 'arithmetic'
# > 1
# ANSWER:  From band get the drink attribute and set it to 'arithmetic'.
#
#
# church.breath(airplane, cream, condition)
# > 5
# ANSWER:  From church get the breath function, and call it with parameters self, airplane, cream, condition.
#
#
# class Apple(object):
# 	def arch(self, cord, doll)
# > 5
# ANSWER:  class Apple has-a function named arch that takes self and cord, doll parameters.
#
#
# degree = Brain()
# > 5
# ANSWER:  Set degree to an instance of class Brain.
#
#
# cup = Box()
# > 5
# ANSWER:  Set cup to an instance of class Box.
#
#
# detail.chicken(canvas, birth, cloth)
# > 5
# ANSWER:  From detail get the chicken function, and call it with parameters self, canvas, birth, cloth.
#
#
# class Crush(object):
# 	def __init__(self, box)
# > 5
# ANSWER:  class Crush has-a __init__ that takes self and box parameters.
#
#
# class Bath(object):
# 	def butto(self, copper)
# > 5
# ANSWER:  class Bath has-a function named butto that takes self and copper parameters.
#
#
# driving.cattle = 'cloud'
# > 5
# ANSWER:  From driving get the cattle attribute and set it to 'cloud'.
#
#
# class Church(Disgust):
# > 5
# ANSWER:  Make a class named Church that is-a Disgust.
#
#
# bedroom.distribution(cloud)
# > 5
# ANSWER:  From bedroom get the distribution function, and call it with parameters self, cloud.
#
#
# decision.blade = 'club'
# > 5
# ANSWER:  From decision get the blade attribute and set it to 'club'.
#
#
# class Beef(Aunt):
# > 5
# ANSWER:  Make a class named Beef that is-a Aunt.
#
#
# class Band(object):
# 	def __init__(self, argument)
# > 5
# ANSWER:  class Band has-a __init__ that takes self and argument parameters.
#
#
# doll = Beef()
# > 58
# ANSWER:  Set doll to an instance of class Beef.
#
#
# class Drink(object):
# 	def desk(self, company, basketball, detail)
# > 7
# ANSWER:  class Drink has-a function named desk that takes self and company, basketball, detail parameters.
#
#
# baby.brush = 'boat'
# > 4
# ANSWER:  From baby get the brush attribute and set it to 'boat'.
#
#
# class Cattle(object):
# 	def __init__(self, band)
# > 1
# ANSWER:  class Cattle has-a __init__ that takes self and band parameters.
#
#
# border.boot(cough, cloud, brain)
# > 1
# ANSWER:  From border get the boot function, and call it with parameters self, cough, cloud, brain.
#
#
# business = Color()
# > red
# ANSWER:  Set business to an instance of class Color.
#
#
# class Creature(Design):
# > yes
# ANSWER:  Make a class named Creature that is-a Design.
#
#
# class Canvas(object):
# 	def doll(self, boot, cracker)
# > function
# ANSWER:  class Canvas has-a function named doll that takes self and boot, cracker parameters.
#
#
# class Arch(object):
# 	def __init__(self, debt)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-8b9d968e2ca4> in <module>
#      73             print(question)
#      74
# ---> 75             input("> ")
#      76             print("ANSWER:  %s\n\n" % answer)
#      77 except EOFError:
#
# c:\users\ali\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# c:\users\ali\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
